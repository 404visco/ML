# %%
import pandas as pd
import os
import numpy as np

from sklearn.metrics import f1_score


import warnings
warnings.filterwarnings("ignore")

# %%
data_sources= {
    'ISPU': "C:/Users/visco/Downloads/penyisihan-datavidia-10/ISPU/",
    'cuaca-harian': "C:/Users/visco/Downloads/penyisihan-datavidia-10/cuaca-harian/",
    'jumlah-penduduk': "C:/Users/visco/Downloads/penyisihan-datavidia-10/jumlah-penduduk/data-jumlah-penduduk-provinsi-dki-jakarta-berdasarkan-kelompok-usia-dan-jenis-kelamin-tahun-2013-2021-komponen-data.csv",
    'kualitas-air-sungai':"C:/Users/visco/Downloads/penyisihan-datavidia-10/kualitas-air-sungai/data-kualitas-air-sungai-komponen-data.csv",
    'libur-nasional': "C:/Users/visco/Downloads/penyisihan-datavidia-10/libur-nasional/dataset-libur-nasional-dan-weekend.csv",
    'NDVI': "C:/Users/visco/Downloads/penyisihan-datavidia-10/NDVI (vegetation index)/indeks-ndvi-jakarta.csv"
}

# %%
ispu_files= os.listdir(data_sources['ISPU'])
cuaca_files= os.listdir(data_sources['cuaca-harian'])
print(ispu_files)
print(cuaca_files)
